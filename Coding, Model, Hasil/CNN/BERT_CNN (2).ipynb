# %% [markdown]
# # Automatic Recognition of Persuasive Content on Electronic News

# %% [markdown]
# https://colab.research.google.com/github/dipanjanS/nlp_workshop_odsc19/blob/master/Module05%20-%20NLP%20Applications/Project06%20-%20Text%20Summarization.ipynb

# %% [markdown]
# # Install Lib

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install Sastrawi
# !pip install nlp-id
# !pip install transformers
# !pip install torch
# !pip install tensorflow
# !pip install bertviz
# !pip install joblib
# !pip install networkx==2.6.
# !pip install transformers==4.31.0

import nltk
import tensorflow as tf
import numpy as np

from nltk.corpus import stopwords
from keras.preprocessing import sequence
nltk.download("popular")
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# Collecting Sastrawi
#   Using cached Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Using cached Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting nlp-id
#   Downloading nlp_id-0.1.18.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting huggingface-hub==0.23.4 (from nlp-id)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Collecting nltk==3.9.1 (from nlp-id)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy==1.26.4 in c:\users\asiyah\anaconda3\lib\site-packages (from nlp-id) (1.26.4)
# Collecting scikit-learn==1.5.1 (from nlp-id)
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting scipy==1.13.1 (from nlp-id)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# Collecting wget==3.2 (from nlp-id)
#   Using cached wget-3.2-py3-none-any.whl
# Requirement already satisfied: filelock in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (6.0.1)
# Requirement already satisfied: requests in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub==0.23.4->nlp-id) (4.9.0)
# Requirement already satisfied: click in c:\users\asiyah\anaconda3\lib\site-packages (from nltk==3.9.1->nlp-id) (8.1.7)
# Requirement already satisfied: joblib in c:\users\asiyah\anaconda3\lib\site-packages (from nltk==3.9.1->nlp-id) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asiyah\anaconda3\lib\site-packages (from nltk==3.9.1->nlp-id) (2023.10.3)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.5.1->nlp-id)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\asiyah\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub==0.23.4->nlp-id) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->huggingface-hub==0.23.4->nlp-id) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->huggingface-hub==0.23.4->nlp-id) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->huggingface-hub==0.23.4->nlp-id) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->huggingface-hub==0.23.4->nlp-id) (2024.2.2)
# Downloading nlp_id-0.1.18.0-py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB 5.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 0
MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.4/46.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.9/46.2 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.5/46.2 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.1/46.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 41.6/46.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 42.2/46.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 42.8/46.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/46.2 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 43.9/46.2 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.5/46.2 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  45.1/46.2 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  45.5/46.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 10.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: wget, threadpoolctl, scipy, scikit-learn, nltk, huggingface-hub, nlp-id
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.6
#     Uninstalling huggingface-hub-0.24.6:
#       Successfully uninstalled huggingface-hub-0.24.6
# Successfully installed huggingface-hub-0.23.4 nlp-id-0.1.18.0 nltk-3.9.1 scikit-learn-1.5.1 scipy-1.13.1 threadpoolctl-3.5.0 wget-3.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Asiyah\anaconda3\Lib\site-packages\~cipy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Asiyah\anaconda3\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# Requirement already satisfied: transformers in c:\users\asiyah\anaconda3\lib\site-packages (4.31.0)
# Requirement already satisfied: filelock in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.9.0)
# Requirement already satisfied: colorama in c:\users\asiyah\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers) (2024.2.2)
# Collecting torch
#   Downloading torch-2.4.0-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: filelock in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\asiyah\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asiyah\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asiyah\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Downloading torch-2.4.0-cp311-cp311-win_amd64.whl (197.9 MB)
#    ---------------------------------------- 0.0/197.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/197.9 MB 2.2 MB/s eta 0:01:29
#    ---------------------------------------- 0.4/197.9 MB 4.5 MB/s eta 0:00:45
#    ---------------------------------------- 0.9/197.9 MB 6.0 MB/s eta 0:00:33
#    ---------------------------------------- 1.4/197.9 MB 7.6 MB/s eta 0:00:26
#    ---------------------------------------- 1.6/197.9 MB 8.3 MB/s eta 0:00:24
#    ---------------------------------------- 2.0/197.9 MB 7.5 MB/s eta 0:00:27
#     --------------------------------------- 3.0/197.9 MB 9.6 MB/s eta 0:00:21
#     --------------------------------------- 3.0/197.9 MB 9.6 MB/s eta 0:00:21
#     --------------------------------------- 4.2/197.9 MB 10.2 MB/s eta 0:00:20
#     --------------------------------------- 4.7/197.9 MB 10.4 MB/s eta 0:00:19
MB 11.9 MB/s eta 0:00:02
#    ----------------------------------- --- 181.8/197.9 MB 11.9 MB/s eta 0:00:02
#    ----------------------------------- --- 182.3/197.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------ -- 182.8/197.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------ -- 183.4/197.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------ -- 183.9/197.9 MB 12.4 MB/s eta 0:00:02
#    ------------------------------------ -- 184.5/197.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------ -- 185.0/197.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------ -- 185.6/197.9 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------ -- 186.1/197.9 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------ -- 186.7/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ -- 187.2/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 187.7/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 188.2/197.9 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- - 188.7/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 189.3/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 189.8/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 190.4/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 190.9/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 191.5/197.9 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- - 192.0/197.9 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- - 192.6/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  193.2/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  193.7/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  194.3/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  194.8/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  195.4/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  195.9/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  196.5/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  197.0/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  197.6/197.9 MB 11.9 MB/s eta 0:00:01
#    --------------------------------------  197.9/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  197.9/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  197.9/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  197.9/197.9 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  197.9/197.9 MB 11.7 MB/s eta 0:00:01
# ...
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (6.0.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.4.4)
# Requirement already satisfied: colorama in c:\users\asiyah\anaconda3\lib\site-packages (from tqdm->bertviz) (0.4.6)
# Collecting botocore<1.36.0,>=1.35.3 (from boto3->bertviz)
#   Downloading botocore-1.35.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\asiyah\anaconda3\lib\site-packages (from boto3->bertviz) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->bertviz)
#   Using cached s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->bertviz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->bertviz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->bertviz) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->bertviz) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\asiyah\anaconda3\lib\site-packages (from botocore<1.36.0,>=1.35.3->boto3->bertviz) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asiyah\anaconda3\lib\site-packages (from jinja2->torch>=1.0->bertviz) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asiyah\anaconda3\lib\site-packages (from sympy->torch>=1.0->bertviz) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\asiyah\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.3->boto3->bertviz) (1.16.0)
# Using cached bertviz-1.4.0-py3-none-any.whl (157 kB)
# Downloading boto3-1.35.3-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.1 kB ? eta -:--:--
#    ----------- --------------------------- 41.0/139.1 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 139.1/139.1 kB 2.0 MB/s eta 0:00:00
# Using cached sentencepiece-0.2.0-cp311-cp311-win_amd64.whl (991 kB)
# Downloading botocore-1.35.3-py3-none-any.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.5 MB 11.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/12.5 MB 11.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/12.5 MB 9.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/12.5 MB 9.6 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.5 MB 9.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.5 MB 8.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.5/12.5 MB 9.6 MB/s eta 0:00:01
#    ------------ --------------------------- 4.0/12.5 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/12.5 MB 10.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.5 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.5 MB 10.4 MB/s eta 0:00:01
#    -------------------- ------------------- 6.3/12.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.5 MB 10.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.4/12.5 MB 10.8 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.5 MB 10.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.5/12.5 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.1/12.5 MB 11.0 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.5 MB 11.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.8/12.5 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.5 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.5 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  12.5/12.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 11.5 MB/s eta 0:00:00
# Using cached s3transfer-0.10.2-py3-none-any.whl (82 kB)
# Installing collected packages: sentencepiece, botocore, s3transfer, boto3, bertviz
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.31.64
#     Uninstalling botocore-1.31.64:
#       Successfully uninstalled botocore-1.31.64
# Successfully installed bertviz-1.4.0 boto3-1.35.3 botocore-1.35.3 s3transfer-0.10.2 sentencepiece-0.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.7.0 requires botocore<1.31.65,>=1.31.16, but you have botocore 1.35.3 which is incompatible.
# Requirement already satisfied: joblib in c:\users\asiyah\anaconda3\lib\site-packages (1.2.0)
# Collecting networkx==2.6.
#   Downloading networkx-2.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.19 in c:\users\asiyah\anaconda3\lib\site-packages (from networkx==2.6.) (1.26.4)
# Requirement already satisfied: scipy!=1.6.1,>=1.5 in c:\users\asiyah\anaconda3\lib\site-packages (from networkx==2.6.) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\asiyah\anaconda3\lib\site-packages (from networkx==2.6.) (3.8.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\asiyah\anaconda3\lib\site-packages (from networkx==2.6.) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asiyah\anaconda3\lib\site-packages (from matplotlib>=3.3->networkx==2.6.) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asiyah\anaconda3\lib\site-packages (from pandas>=1.1->networkx==2.6.) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asiyah\anaconda3\lib\site-packages (from pandas>=1.1->networkx==2.6.) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\asiyah\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->networkx==2.6.) (1.16.0)
# Downloading networkx-2.6-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB 682.7 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.9 MB 2.0 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/1.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/1.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/1.9 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed networkx-2.6
# WARNING: The candidate selected for download or install is a yanked version: 'networkx' candidate (version 2.6 at https://files.pythonhosted.org/packages/b2/87/30ed9e62d5459bbf22b335fc2d9d1faf979d44b1c55a1f0455da0afd756e/networkx-2.6-py3-none-any.whl (from https://pypi.org/simple/networkx/) (requires-python:>=3.7))
# Reason for being yanked: Need to resolve: https://github.com/networkx/networkx/pull/4967
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.22.0 requires networkx>=2.8, but you have networkx 2.6 which is incompatible.
# Requirement already satisfied: transformers==4.31.0 in c:\users\asiyah\anaconda3\lib\site-packages (4.31.0)
# Requirement already satisfied: filelock in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (2023.10.3)
# Requirement already satisfied: requests in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asiyah\anaconda3\lib\site-packages (from transformers==4.31.0) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asiyah\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (4.9.0)
# Requirement already satisfied: colorama in c:\users\asiyah\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.31.0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers==4.31.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers==4.31.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers==4.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asiyah\anaconda3\lib\site-packages (from requests->transformers==4.31.0) (2024.2.2)
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Asiyah\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %% [markdown]
# # Init Data

# %%
from io import BytesIO

import requests
import pandas as pd

r = requests.get('https://docs.google.com/spreadsheet/ccc?key=1i3BBozbnx9HSTkMsfMHChvzYwG_2MiFB06U05gitD8U&output=xlsx')
data = r.content
dataset = pd.read_excel(data, 'Prepocessed (3)')
dataset
# Out:
# C:\Users\Asiyah\AppData\Local\Temp\ipykernel_31276\3219960653.py:8: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   dataset = pd.read_excel(data, 'Prepocessed (3)')
#       id-berita                                                url  \
# 0           229  https://tekno.sindonews.com/read/807727/776/pe...
# 1           229  https://tekno.sindonews.com/read/807727/776/pe...
# 2           229  https://tekno.sindonews.com/read/807727/776/pe...
# 3           229  https://tekno.sindonews.com/read/807727/776/pe...
# 4           229  https://tekno.sindonews.com/read/807727/776/pe...
# ...         ...                                                ...
# 2497        998  https://cnnindonesia.com/teknologi/20221203102...
# 2498        998  https://cnnindonesia.com/teknologi/20221203102...
# 2499        998  https://cnnindonesia.com/teknologi/20221203102...
# 2500        998  https://cnnindonesia.com/teknologi/20221203102...
# 2501        998  https://cnnindonesia.com/teknologi/20221203102...
#
#                                                   judul  \
# 0     Pengertian Absen Online dan Kelebihannya Diban...
# 1     Pengertian Absen Online dan Kelebihannya Diban...
# 2     Pengertian Absen Online dan Kelebihannya Diban...
# 3     Pengertian Absen Online dan Kelebihannya Diban...
# 4     Pengertian Absen Online dan Kelebihannya Diban...
# ...                                                 ...
# 2497  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2498  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2499  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2500  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2501  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
#
#                                    content per paragraf  label-positif  \
# 0     Absen Online kini mulai merambah ke berbagai p...              0
# 1     Sebelum mengetahui manfaat absen online bagi p...              1
# 2     Semua data tersebut selanjutnya akan diberikan...              1
# 3     Setiap hari karyawan melakukan absen dengan me...              1
# 4     Sementara, Absen online merupakan sistem absen...              1
# ...                                                 ...            ...
# 2497  Donald Trump yang menjadi lawan Biden sekaligu...             -1
# 2498  Dalam utas tersebut, Taibbi mengatakan bahwa a...              0
# 2499  Namun menurut Taibbi, Twitter pelan-pelan mala...             -1
# 2500  Taibbi juga menyebut sejumlah partai politik m...             -1
# 2501  Mereka bahkan memblok transmisi sendiri via pe...             -1
#
#       label-persuasif  label-produk  perspektif-tunggal  label-berita  labels  \
# 0                   0             1                   1    native ads       1
# 1                   1             1                   1    native ads       1
# 2                   0             1                   1    native ads       1
# 3                   1             0                   1    native ads       1
# 4                   1             1                   1    native ads       1
# ...               ...           ...                 ...           ...     ...
# 2497                0             0                   1  berita murni       0
# 2498                0             0                   1  berita murni       0
# 2499                0             0                   0  berita murni       0
# 2500                0             1                   1  berita murni       0
# 2501                0             0                   1  berita murni       0
#
#                                           content_lower  \
# 0     absen online kini mulai merambah ke berbagai p...
# 1     sebelum mengetahui manfaat absen online bagi p...
# 2     semua data tersebut selanjutnya akan diberikan...
# 3     setiap hari karyawan melakukan absen dengan me...
# 4     sementara, absen online merupakan sistem absen...
# ...                                                 ...
# 2497  donald trump yang menjadi lawan biden sekaligu...
# 2498  dalam utas tersebut, taibbi mengatakan bahwa a...
# 2499  namun menurut taibbi, twitter pelan-pelan mala...
# 2500  taibbi juga menyebut sejumlah partai politik m...
# 2501  mereka bahkan memblok transmisi sendiri via pe...
#
#                                           content_punct  \
# 0     absen online kini mulai merambah ke berbagai p...
# 1     sebelum mengetahui manfaat absen online bagi p...
# 2     semua data tersebut selanjutnya akan diberikan...
# 3     setiap hari karyawan melakukan absen dengan me...
# 4     sementara, absen online merupakan sistem absen...
# ...                                                 ...
# 2497   donald trump yang menjadi lawan biden sekalig...
# 2498  dalam utas tersebut, taibbi mengatakan bahwa a...
# 2499  namun menurut taibbi, twitter pelan-pelan mala...
# 2500  taibbi juga menyebut sejumlah partai politik m...
# 2501  mereka bahkan memblok transmisi sendiri via pe...
#
#                                           content_lemma  \
# 0     absen online kini mulai rambah ke bagai usaha ...
# 1     belum tahu manfaat absen online bagi usaha mar...
# 2     semua data sebut lanjut akan beri kepada hrd y...
# 3     tiap hari karyawan laku absen dengan tulis jam...
# 4     sementara absen online rupa sistem absensi yan...
# ...                                                 ...
# 2497  donald trump yang jadi lawan biden sekaligus t...
# 2498  dalam utas sebut taibbi kata bahwa apa yang ak...
# 2499  namun turut taibbi twitter pelan malah tambah ...
# 2500  taibbi juga sebut jumlah partai politik milik ...
# 2501  mereka bahkan blok transmisi sendiri via pesan...
#
#                                           content_token  \
# 0     ['absen', 'online', 'rambah', 'usaha', 'ganti'...
# 1     ['manfaat', 'absen', 'online', 'usaha', 'mari'...
# 2     ['data', 'hrd', 'tanggung', 'gaji', 'karyawan'...
# 3     ['karyawan', 'laku', 'absen', 'tulis', 'jam', ...
# 4     ['absen', 'online', 'rupa', 'sistem', 'absensi...
# ...                                                 ...
# 2497  ['donald', 'trump', 'lawan', 'biden', 'tahana'...
# 2498  ['utas', 'taibbi', 'baca', 'cuplik', 'buah', '...
# 2499  ['taibbi', 'twitter', 'pelan', 'halang', 'hala...
# 2500  ['taibbi', 'partai', 'politik', 'milik', 'akse...
# 2501  ['blok', 'transmisi', 'via', 'pesan', 'langsun...
#
#                                       content_stopwords
# 0     absen online rambah usaha ganti absen manual r...
# 1     manfaat absen online usaha mari ajar erti lapo...
# 2     data hrd tanggung gaji karyawan data hrd rugi ...
# 3     karyawan laku absen tulis jam hadir tanda tang...
# 4     absen online rupa sistem absensi manfaat jarin...
# ...                                                 ...
# 2497  donald trump lawan biden tahana coba serang bi...
# 2498  utas taibbi baca cuplik buah serial dasar ribu...
# 2499  taibbi twitter pelan halang halang alat kontro...
# 2500  taibbi partai politik milik akses hadap alat c...
# 2501  blok transmisi via pesan langsung dm buah alat...
#
# [2502 rows x 15 columns]

# %%
len(dataset)
# Out:
# 2502

# %%
dataset
# Out:
#       id-berita                                                url  \
# 0           229  https://tekno.sindonews.com/read/807727/776/pe...
# 1           229  https://tekno.sindonews.com/read/807727/776/pe...
# 2           229  https://tekno.sindonews.com/read/807727/776/pe...
# 3           229  https://tekno.sindonews.com/read/807727/776/pe...
# 4           229  https://tekno.sindonews.com/read/807727/776/pe...
# ...         ...                                                ...
# 2497        998  https://cnnindonesia.com/teknologi/20221203102...
# 2498        998  https://cnnindonesia.com/teknologi/20221203102...
# 2499        998  https://cnnindonesia.com/teknologi/20221203102...
# 2500        998  https://cnnindonesia.com/teknologi/20221203102...
# 2501        998  https://cnnindonesia.com/teknologi/20221203102...
#
#                                                   judul  \
# 0     Pengertian Absen Online dan Kelebihannya Diban...
# 1     Pengertian Absen Online dan Kelebihannya Diban...
# 2     Pengertian Absen Online dan Kelebihannya Diban...
# 3     Pengertian Absen Online dan Kelebihannya Diban...
# 4     Pengertian Absen Online dan Kelebihannya Diban...
# ...                                                 ...
# 2497  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2498  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2499  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2500  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
# 2501  Elon Musk Sebut Twitter Tutupi Cerita Kontrove...
#
#                                    content per paragraf  label-positif  \
# 0     Absen Online kini mulai merambah ke berbagai p...              0
# 1     Sebelum mengetahui manfaat absen online bagi p...              1
# 2     Semua data tersebut selanjutnya akan diberikan...              1
# 3     Setiap hari karyawan melakukan absen dengan me...              1
# 4     Sementara, Absen online merupakan sistem absen...              1
# ...                                                 ...            ...
# 2497  Donald Trump yang menjadi lawan Biden sekaligu...             -1
# 2498  Dalam utas tersebut, Taibbi mengatakan bahwa a...              0
# 2499  Namun menurut Taibbi, Twitter pelan-pelan mala...             -1
# 2500  Taibbi juga menyebut sejumlah partai politik m...             -1
# 2501  Mereka bahkan memblok transmisi sendiri via pe...             -1
#
#       label-persuasif  label-produk  perspektif-tunggal  label-berita  labels  \
# 0                   0             1                   1    native ads       1
# 1                   1             1                   1    native ads       1
# 2                   0             1                   1    native ads       1
# 3                   1             0                   1    native ads       1
# 4                   1             1                   1    native ads       1
# ...               ...           ...                 ...           ...     ...
# 2497                0             0                   1  berita murni       0
# 2498                0             0                   1  berita murni       0
# 2499                0             0                   0  berita murni       0
# 2500                0             1                   1  berita murni       0
# 2501                0             0                   1  berita murni       0
#
#                                           content_lower  \
# 0     absen online kini mulai merambah ke berbagai p...
# 1     sebelum mengetahui manfaat absen online bagi p...
# 2     semua data tersebut selanjutnya akan diberikan...
# 3     setiap hari karyawan melakukan absen dengan me...
# 4     sementara, absen online merupakan sistem absen...
# ...                                                 ...
# 2497  donald trump yang menjadi lawan biden sekaligu...
# 2498  dalam utas tersebut, taibbi mengatakan bahwa a...
# 2499  namun menurut taibbi, twitter pelan-pelan mala...
# 2500  taibbi juga menyebut sejumlah partai politik m...
# 2501  mereka bahkan memblok transmisi sendiri via pe...
#
#                                           content_punct  \
# 0     absen online kini mulai merambah ke berbagai p...
# 1     sebelum mengetahui manfaat absen online bagi p...
# 2     semua data tersebut selanjutnya akan diberikan...
# 3     setiap hari karyawan melakukan absen dengan me...
# 4     sementara, absen online merupakan sistem absen...
# ...                                                 ...
# 2497   donald trump yang menjadi lawan biden sekalig...
# 2498  dalam utas tersebut, taibbi mengatakan bahwa a...
# 2499  namun menurut taibbi, twitter pelan-pelan mala...
# 2500  taibbi juga menyebut sejumlah partai politik m...
# 2501  mereka bahkan memblok transmisi sendiri via pe...
#
#                                           content_lemma  \
# 0     absen online kini mulai rambah ke bagai usaha ...
# 1     belum tahu manfaat absen online bagi usaha mar...
# 2     semua data sebut lanjut akan beri kepada hrd y...
# 3     tiap hari karyawan laku absen dengan tulis jam...
# 4     sementara absen online rupa sistem absensi yan...
# ...                                                 ...
# 2497  donald trump yang jadi lawan biden sekaligus t...
# 2498  dalam utas sebut taibbi kata bahwa apa yang ak...
# 2499  namun turut taibbi twitter pelan malah tambah ...
# 2500  taibbi juga sebut jumlah partai politik milik ...
# 2501  mereka bahkan blok transmisi sendiri via pesan...
#
#                                           content_token  \
# 0     ['absen', 'online', 'rambah', 'usaha', 'ganti'...
# 1     ['manfaat', 'absen', 'online', 'usaha', 'mari'...
# 2     ['data', 'hrd', 'tanggung', 'gaji', 'karyawan'...
# 3     ['karyawan', 'laku', 'absen', 'tulis', 'jam', ...
# 4     ['absen', 'online', 'rupa', 'sistem', 'absensi...
# ...                                                 ...
# 2497  ['donald', 'trump', 'lawan', 'biden', 'tahana'...
# 2498  ['utas', 'taibbi', 'baca', 'cuplik', 'buah', '...
# 2499  ['taibbi', 'twitter', 'pelan', 'halang', 'hala...
# 2500  ['taibbi', 'partai', 'politik', 'milik', 'akse...
# 2501  ['blok', 'transmisi', 'via', 'pesan', 'langsun...
#
#                                       content_stopwords
# 0     absen online rambah usaha ganti absen manual r...
# 1     manfaat absen online usaha mari ajar erti lapo...
# 2     data hrd tanggung gaji karyawan data hrd rugi ...
# 3     karyawan laku absen tulis jam hadir tanda tang...
# 4     absen online rupa sistem absensi manfaat jarin...
# ...                                                 ...
# 2497  donald trump lawan biden tahana coba serang bi...
# 2498  utas taibbi baca cuplik buah serial dasar ribu...
# 2499  taibbi twitter pelan halang halang alat kontro...
# 2500  taibbi partai politik milik akses hadap alat c...
# 2501  blok transmisi via pesan langsung dm buah alat...
#
# [2502 rows x 15 columns]

# %%
import re

def changeQuotation(text):
  text = re.sub(r'"',r'“', text)
  return text

# %%
dataset['content per paragraf'] = dataset['content per paragraf'].apply(changeQuotation)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

def feature_engineering(content):
  tv = TfidfVectorizer(min_df=0., max_df=1., use_idf=True)
  dt_matrix = tv.fit_transform(content)
  dt_matrix = dt_matrix.toarray()

  vocab = tv.get_feature_names_out()
  td_matrix = dt_matrix.T
  return td_matrix,dt_matrix

# %% [markdown]
# ## Split dataset

# %%
# Misalkan menggunakan `content_lemma` sebagai input
texts = dataset['content_lemma'].values
# Variabel target y adalah kombinasi dari empat label
y = dataset['labels'].values

# %%
# x_train1,y_train,x_test1,y_test = train_test_split(embed1,y,80)
# x_train1,x_test1,y_train,y_test = train_test_split(embed1, y, test_size=0.3, random_state=0)
from sklearn.model_selection import KFold

# kf = KFold(n_splits=4)           #KFold(n_splits=’warn’, shuffle=False, random_state=None)
kf = KFold(5,shuffle=True, random_state=0) # Use for KFold classification

for train_index, validation_index in kf.split(texts):
   #print("TRAIN:", texts[train_index], "VALIDATION:", texts[validation_index])
   x_train, x_test = texts[train_index], texts[validation_index]
   y_train, y_test = y[train_index], y[validation_index]

# %%
import matplotlib.pyplot as plt

df_train = pd.DataFrame(list(zip(x_train, y_train)), columns=['content_lemma', 'labels'])
df_train.groupby(['labels']).size().plot(kind='bar')
plt.title('Distribusi Label Berita pada Data Testing')
print(df_train.shape)
# Out:
# (2002, 2)

# %%
df_test = pd.DataFrame(list(zip(x_test, y_test)), columns=['content_lemma', 'labels'])
df_test.groupby(['labels']).size().plot(kind='bar')
plt.title('Distribusi Label Berita pada Data Testing')
print(df_test.shape)
# Out:
# (500, 2)

# %% [markdown]
# # Word Embedding (BERT)

# %%
from transformers import BertForSequenceClassification, BertConfig, BertTokenizer, BertModel
from transformers import TFBertModel
#tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1', do_lower_case=True)
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1', do_lower_case=True)
indobert = TFBertModel.from_pretrained('indobenchmark/indobert-base-p1', from_pt=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 #tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1', do_lower_case=True)
#       4 tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1', do_lower_case=True)
# ----> 5 indobert = TFBertModel.from_pretrained('indobenchmark/indobert-base-p1', from_pt=True)
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py:2880, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, *model_args, **kwargs)
#    2877     from .modeling_tf_pytorch_utils import load_pytorch_checkpoint_in_tf2_model
#    2879     # Load from a PyTorch checkpoint
# -> 2880     return load_pytorch_checkpoint_in_tf2_model(
#    2881         model,
#    2882         resolved_archive_file,
#    2883         allow_missing_keys=True,
#    2884         output_loading_info=output_loading_info,
#    2885         _prefix=load_weight_prefix,
#    2886         tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#    2887     )
#    2889 # we might need to extend the variable scope for composite models
#    2890 if load_weight_prefix is not None:
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_pytorch_utils.py:189, in load_pytorch_checkpoint_in_tf2_model(tf_model, pytorch_checkpoint_path, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename)
#     185     pt_state_dict.update(torch.load(pt_path, map_location="cpu"))
#     187 logger.info(f"PyTorch checkpoint contains {sum(t.numel() for t in pt_state_dict.values()):,} parameters")
# --> 189 return load_pytorch_weights_in_tf2_model(
#     190     tf_model,
#     191     pt_state_dict,
#     192     tf_inputs=tf_inputs,
#     193     allow_missing_keys=allow_missing_keys,
#     194     output_loading_info=output_loading_info,
#     195     _prefix=_prefix,
#     196     tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#     197 )
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_pytorch_utils.py:230, in load_pytorch_weights_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename)
#     227     raise
#     229 pt_state_dict = {k: v.numpy() for k, v in pt_state_dict.items()}
# --> 230 return load_pytorch_state_dict_in_tf2_model(
#     231     tf_model,
#     232     pt_state_dict,
#     233     tf_inputs=tf_inputs,
#     234     allow_missing_keys=allow_missing_keys,
#     235     output_loading_info=output_loading_info,
#     236     _prefix=_prefix,
#     237     tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#     238 )
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_pytorch_utils.py:263, in load_pytorch_state_dict_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename, ignore_mismatched_sizes)
#     261 if tf_inputs:
#     262     with tf.name_scope(_prefix):
# --> 263         tf_model(tf_inputs, training=False)  # Make sure model is built
#     264 # Convert old format to new format if needed from a PyTorch state_dict
#     265 tf_keys_to_pt_keys = {}
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py:1131, in TFPreTrainedModel.build(self, input_shape)
#    1129 def build(self, input_shape=None):
#    1130     call_context = get_call_context_function()
# -> 1131     if self.built or call_context().in_call:
#    1132         self.built = True
#    1133     else:
#
# TypeError: 'NoneType' object is not callable

# %%
#model = BertModel.from_pretrained('indobenchmark/indobert-base-p1', output_hidden_states = True)
#model.eval()

# %%
max_len = 257
def encode_texts(text_list):
   # Inisialisasi list untuk menampung hasil
    input_ids = []
    attention_masks = []

    for text in text_list:
        encoded_dict = tokenizer.encode_plus(
            text,
            add_special_tokens=True,  # Tambahkan [CLS] dan [SEP]
            max_length=max_len,
            padding='max_length',
            truncation=True,  # Aktifkan pemotongan jika teks lebih panjang
            return_tensors='tf',  # Mengembalikan TensorFlow tensors
            return_attention_mask=True  # Menghasilkan attention mask
        )
        input_ids.append(encoded_dict['input_ids'])
        attention_masks.append(encoded_dict['attention_mask'])

    return {'input_ids': tf.concat(input_ids, axis=0), 'attention_mask': tf.concat(attention_masks, axis=0)}

# %%
# Encode data training dan testing
train_encodings = encode_texts(x_train)
test_encodings = encode_texts(x_test)

# %%
# build model fine tuning bert
# def get_embeddings(encoded_texts, batch_size=16):
#     outputs = indobert(encoded_texts['input_ids'], attention_mask=encoded_texts['attention_mask'])
#     return outputs.last_hidden_state  # Mengambil output embeddings

# Function to get embeddings with smaller batch size
def get_embeddings(encoded_texts, batch_size=16):
    embeddings = []
    for i in range(0, len(encoded_texts['input_ids']), batch_size):
        batch_input_ids = encoded_texts['input_ids'][i:i+batch_size]
        batch_attention_mask = encoded_texts['attention_mask'][i:i+batch_size]
        outputs = indobert(batch_input_ids, attention_mask=batch_attention_mask)
        embeddings.append(outputs.last_hidden_state)
    return tf.concat(embeddings, axis=0)

# Mendapatkan embeddings untuk data training dan testing
train_embeddings = get_embeddings(train_encodings)
test_embeddings = get_embeddings(test_encodings)

# %%
# import torch
# # Forward pass, dapatkan hidden states
# with torch.no_grad():
#     outputs = model()
#     hidden_states = outputs[2]

# %%
from tensorflow.keras.layers import Input
# Input untuk token IDs dan attention mask
input_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
attention_mask = Input(shape=(max_len,), dtype=tf.int32, name="attention_mask")

# %%
# Verifikasi tipe dan shape dari input_ids dan attention_mask
print(f"Type of input_ids: {type(input_ids)}")
print(f"Shape of input_ids: {input_ids.shape}")
print(f"Type of attention_mask: {type(attention_mask)}")
print(f"Shape of attention_mask: {attention_mask.shape}")

# %% [markdown]
# # Save Embedding Model

# %%
# Step 1: Menyimpan embedding matrix
train_npy = 'tesis/Thesis Persuasive Detection at Paragraph-Level/Embeddings Model/BERT_train.npy'
test_npy = 'tesis/Thesis Persuasive Detection at Paragraph-Level/Embeddings Model/BERT_test.npy'

# Simpan embedding matrix ke dalam file .npy
np.save(train_npy, train_embeddings)
np.save(test_npy, test_embeddings)
print(f"Embedding matrix saved to .../Thesis Persuasive Detection at Paragraph-Level  /Embedding Models/")

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
from transformers import TFBertModel, BertTokenizer

class BertLayer(Layer):
    def __init__(self, **kwargs):
        super(BertLayer, self).__init__(**kwargs)
        self.indobert = TFBertModel.from_pretrained('indobenchmark/indobert-base-p1', from_pt=True)

    def call(self, inputs):
        input_ids, attention_mask = inputs
        output = self.indobert(input_ids, attention_mask=attention_mask)
        return output.last_hidden_state

# Definisikan input Keras
input_ids = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
attention_mask = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="attention_mask")

# Gunakan BertLayer di dalam model Keras
bert_output = BertLayer()([input_ids, attention_mask])

# %%
# Mendapatkan embeddings dari IndoBERT
# bert_output = indobert(input_ids, attention_mask=attention_mask)
sequence_output = bert_output[0]  # Mengambil last_hidden_state
sequence_output

# %%
import tensorflow as tf

out = tf.keras.layers.Conv1D(filters=16, kernel_size=2)(bert_output)
out = tf.keras.layers.BatchNormalization()(out)
out = tf.keras.layers.Dropout(0.2)(out)
out = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, return_sequences=True))(out)
out = tf.keras.layers.GlobalMaxPooling1D()(out)
out = tf.keras.layers.Dropout(0.2)(out)
y = tf.keras.layers.Dense(2, activation="sigmoid")(out)

model = tf.keras.Model(inputs=[input_ids, attention_mask], outputs=y)
model.layers[2].trainable = True

optimizer = tf.keras.optimizers.Adam(learning_rate=2e-05)
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)
metric = tf.keras.metrics.CategoricalAccuracy('balanced_accuracy')

model.compile(optimizer=optimizer, loss=loss, metrics=[metric])
model.summary()

# %%
y_train_dl = tf.keras.utils.to_categorical(y_train)
y_test_dl = tf.keras.utils.to_categorical(y_test)

# %%
history = model.fit(x={'input_ids':train_encodings['input_ids'], 'attention_mask':train_encodings['attention_mask']},
                    y=y_train_dl,
                    validation_data=(
                        {'input_ids':test_encodings['input_ids'], 'attention_mask':test_encodings['attention_mask']},
                    y_test_dl),
                    epochs=10,
                    batch_size=8)

# %%
# Prediction
from sklearn.metrics import classification_report

predicted_raw = model.predict(
    {'input_ids': test_encodings['input_ids'], 'attention_mask': test_encodings['attention_mask']})

y_pred = np.argmax(predicted_raw, axis=1)
y_true = y_test_dl

# Periksa tipe data
print(f'y_true dtype: {y_true.dtype}, shape: {y_true.shape}')
print(f'y_pred dtype: {y_pred.dtype}, shape: {y_pred.shape}')

# Ubah y_true dari one-hot encoded ke label kelas
if y_true.ndim == 2:
    y_true = np.argmax(y_true, axis=1)

print(classification_report(y_true, y_pred))

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

labels = ["Native Ads", "Berita Murni"]

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# ## roc

# %%
from sklearn import metrics

y = np.array(y_true)

scores = np.array(y_pred)
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_pred, pos_label=9)
roc_auc = metrics.auc(fpr, tpr)


plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
 lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_true, y_pred)
auc_rf = auc(fpr_rf, tpr_rf)

# %%
auc_rf

# %% [markdown]
# ##### plt.figure(1)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
# plt.xlabel('False positive rate')
# plt.ylabel('True positive rate')
# plt.title('ROC curve')
# plt.legend(loc='best')
# plt.show()
# # Zoom in view of the upper left corner.
# plt.figure(2)
# plt.xlim(0, 0.2)
# plt.ylim(0.8, 1)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
# plt.xlabel('False positive rate')
# plt.ylabel('True positive rate')
# plt.title('ROC curve (zoomed in at top left)')
# plt.legend(loc='best')
# plt.show()

# %%
def plot_roc_curve(fpr,tpr):
  plt.plot(fpr,tpr)
  plt.axis([0,1,0,1])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC Curve')
  plt.show()

# %%
from sklearn.metrics import roc_curve,roc_auc_score

fpr , tpr , thresholds = roc_curve (y_true, y_pred)

# %%
plot_roc_curve (fpr,tpr)

# %%
roc_auc_score(y_true, y_pred)

# %%
nn_fpr_keras, nn_tpr_keras, nn_thresholds_keras = roc_curve(y_true, y_pred)
auc_keras = auc(nn_fpr_keras, nn_tpr_keras)
print(auc_keras)
plt.plot(nn_fpr_keras, nn_tpr_keras, marker='.', label='Neural Network (auc = %0.3f)' % auc_keras)

# %%
def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)):
        if y_actual[i]==y_hat[i]==1:
           TP += 1
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
        if y_actual[i]==y_hat[i]==0:
           TN += 1
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1

    return(TP, FP, TN, FN)

# %%
perf_measure(y_true, y_pred)

# %%
acc = history.history['balanced_accuracy']
val_acc = history.history['val_balanced_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()
